# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-3/time-travel.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239536-lesson-5-time-travel)

# %% [markdown]
# # Time travel
#
# ## Review
#
# We discussed motivations for human-in-the-loop:
#
# (1) `Approval` - We can interrupt our agent, surface state to a user, and allow the user to accept an action
#
# (2) `Debugging` - We can rewind the graph to reproduce or avoid issues
#
# (3) `Editing` - You can modify the state
#
# We showed how breakpoints can stop the graph at specific nodes or allow the graph to dynamically interrupt itself.
#
# Then we showed how to proceed with human approval or directly edit the graph state with human feedback.
#
# ## Goals
#
# Now, let's show how LangGraph [supports debugging](https://langchain-ai.github.io/langgraph/how-tos/human_in_the_loop/time-travel/) by viewing, re-playing, and even forking from past states.
#
# We call this `time travel`.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langgraph langchain_openai langgraph_sdk langgraph-prebuilt

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")

# %% [markdown]
# Let's build our agent.

# %%
from langchain_openai import ChatOpenAI

def multiply(a: int, b: int) -> int:
    """Multiply a and b.

    Args:
        a: first int
        b: second int
    """
    return a * b

# This will be a tool
def add(a: int, b: int) -> int:
    """Adds a and b.

    Args:
        a: first int
        b: second int
    """
    return a + b

def divide(a: int, b: int) -> float:
    """Divide a by b.

    Args:
        a: first int
        b: second int
    """
    return a / b
def subtract(a: int, b: int) -> float:
    """Subtract b from a.

    Args:
        a: first int
        b: second int
    """
    return a-b

tools = [add, multiply, divide, subtract]
llm = ChatOpenAI(model="gpt-4o")
llm_with_tools = llm.bind_tools(tools)

# %%
from IPython.display import Image, display

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import MessagesState
from langgraph.graph import START, END, StateGraph
from langgraph.prebuilt import tools_condition, ToolNode

from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

# System message
sys_msg = SystemMessage(content="You are a helpful assistant tasked with performing arithmetic on a set of inputs.")

# Node
def assistant(state: MessagesState):
   return {"messages": [llm_with_tools.invoke([sys_msg] + state["messages"])]}

# Graph
builder = StateGraph(MessagesState)

# Define nodes: these do the work
builder.add_node("assistant", assistant)
builder.add_node("tools", ToolNode(tools))

# Define edges: these determine the control flow
builder.add_edge(START, "assistant")
builder.add_conditional_edges(
    "assistant",
    # If the latest message (result) from assistant is a tool call -> tools_condition routes to tools
    # If the latest message (result) from assistant is a not a tool call -> tools_condition routes to END
    tools_condition,
)
builder.add_edge("tools", "assistant")

memory = MemorySaver()
graph = builder.compile(checkpointer=MemorySaver())

# Show
display(Image(graph.get_graph(xray=True).draw_mermaid_png()))

# %% [markdown]
# Let's run it, as before.

# %%
# Input
initial_input = {"messages": HumanMessage(content="Hi, I'm Akshit. Please multiply 15 and 7.")}

# Thread
thread = {"configurable": {"thread_id": "1"}}

# Run the graph until the first interruption
for event in graph.stream(initial_input, thread, stream_mode="values"):
    event['messages'][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Hi, I'm Akshit. Please multiply 15 and 7.
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_np6Jxh541Gw6NyeSos9eBMF0)
#  Call ID: call_np6Jxh541Gw6NyeSos9eBMF0
#   Args:
#     a: 15
#     b: 7
# ================================= Tool Message =================================
# Name: multiply
#
# 105
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_np6Jxh541Gw6NyeSos9eBMF0)
#  Call ID: call_np6Jxh541Gw6NyeSos9eBMF0
#   Args:
#     a: 15
#     b: 7
# ================================= Tool Message =================================
# Name: multiply
#
# 105
# ================================== Ai Message ==================================
#
# Hi Akshit! The result of multiplying 15 and 7 is 105.
# ================================== Ai Message ==================================
#
# Hi Akshit! The result of multiplying 15 and 7 is 105.

# %% [markdown]
# ## Browsing History
#
# We can use `get_state` to look at the **current** state of our graph, given the `thread_id`!

# %%
graph.get_state({'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content="Hi, I'm Akshit. Please multiply 15 and 7.", additional_kwargs={}, response_metadata={}, id='faa74a8e-e7ee-4750-bd64-cf1c4313e2a5'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 169, 'total_tokens': 186, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_65564d8ba5', 'id': 'chatcmpl-CVdMX03NLtFv3TTQedwp9GgiOofLA', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--dfda36c8-9cc6-486b-800c-cd0d5b69e49f-0', tool_calls=[{'name': 'multiply', 'args': {'a': 15, 'b': 7}, 'id': 'call_np6Jxh541Gw6NyeSos9eBMF0', 'type': 'tool_call'}], usage_metadata={'input_tokens': 169, 'output_tokens': 17, 'total_tokens': 186, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='105', name='multiply', id='166ef5fe-66ff-412a-bdf1-8a16d9a58ab7', tool_call_id='call_np6Jxh541Gw6NyeSos9eBMF0'), AIMessage(content='Hi Akshit! The result of multiplying 15 and 7 is 105.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 194, 'total_tokens': 212, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdMZTbwXiYWzXKCoJqaHXDbg38T1', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--33f26043-f6b3-41f2-9d44-1452d1bcb121-0', usage_metadata={'input_tokens': 194, 'output_tokens': 18, 'total_tokens': 212, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b3fbf-40ed-6dd6-8003-8ebfd00f23df'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2025-10-28T12:45:16.126357+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b3fbf-3444-65c4-8002-19e2bc4254f3'}}, tasks=(), interrupts=())

# %% [markdown]
# We can also browse the state history of our agent.
#
# `get_state_history` lets us get the state at all prior steps.

# %%
all_states = [s for s in graph.get_state_history(thread)]

# %%
len(all_states)
# Out:
# 5

# %% [markdown]
# The first element is the current state, just as we got from `get_state`.

# %%
all_states[-2]
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content="Hi, I'm Akshit. Please multiply 15 and 7.", additional_kwargs={}, response_metadata={}, id='faa74a8e-e7ee-4750-bd64-cf1c4313e2a5')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b3fbf-1f88-64a0-8000-97ad8c1ded76'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-10-28T12:45:12.624451+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b3fbf-1f74-6cf6-bfff-2927eb882293'}}, tasks=(PregelTask(id='40acf4eb-2fbe-d274-9d40-1d05f0552f53', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 169, 'total_tokens': 186, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_65564d8ba5', 'id': 'chatcmpl-CVdMX03NLtFv3TTQedwp9GgiOofLA', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--dfda36c8-9cc6-486b-800c-cd0d5b69e49f-0', tool_calls=[{'name': 'multiply', 'args': {'a': 15, 'b': 7}, 'id': 'call_np6Jxh541Gw6NyeSos9eBMF0', 'type': 'tool_call'}], usage_metadata={'input_tokens': 169, 'output_tokens': 17, 'total_tokens': 186, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}),), interrupts=())

# %% [markdown]
# Everything above we can visualize here:
#
# ![fig1.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbb038211b544898570be3_time-travel1.png)

# %% [markdown]
# ## Replaying
#
# We can re-run our agent from any of the prior steps.
#
# ![fig2.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbb038a0bd34b541c78fb8_time-travel2.png)

# %% [markdown]
# Let's look back at the step that recieved human input!

# %%
to_replay = all_states[-2]

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content="Hi, I'm Akshit. Please multiply 15 and 7.", additional_kwargs={}, response_metadata={}, id='faa74a8e-e7ee-4750-bd64-cf1c4313e2a5')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b3fbf-1f88-64a0-8000-97ad8c1ded76'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-10-28T12:45:12.624451+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b3fbf-1f74-6cf6-bfff-2927eb882293'}}, tasks=(PregelTask(id='40acf4eb-2fbe-d274-9d40-1d05f0552f53', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 169, 'total_tokens': 186, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_65564d8ba5', 'id': 'chatcmpl-CVdMX03NLtFv3TTQedwp9GgiOofLA', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--dfda36c8-9cc6-486b-800c-cd0d5b69e49f-0', tool_calls=[{'name': 'multiply', 'args': {'a': 15, 'b': 7}, 'id': 'call_np6Jxh541Gw6NyeSos9eBMF0', 'type': 'tool_call'}], usage_metadata={'input_tokens': 169, 'output_tokens': 17, 'total_tokens': 186, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}),), interrupts=())

# %% [markdown]
# Look at the state.

# %%
to_replay.values
# Out:
# {'messages': [HumanMessage(content="Hi, I'm Akshit. Please multiply 15 and 7.", additional_kwargs={}, response_metadata={}, id='faa74a8e-e7ee-4750-bd64-cf1c4313e2a5')]}

# %% [markdown]
# We can see the next node to call.

# %%
to_replay.next
# Out:
# ('assistant',)

# %% [markdown]
# We also get the config, which tells us the `checkpoint_id` as well as the `thread_id`.

# %%
to_replay.config
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0b3fbf-1f88-64a0-8000-97ad8c1ded76'}}

# %% [markdown]
# To replay from here, we simply pass the config back to the agent!
#
# The graph knows that this checkpoint has aleady been executed.
#
# It just re-plays from this checkpoint!

# %%
for event in graph.stream(None, to_replay.config, stream_mode="values"):
    event['messages'][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Hi, I'm Akshit. Please multiply 15 and 7.
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_RThqJug1SnaO4e5JIyOJLsZA)
#  Call ID: call_RThqJug1SnaO4e5JIyOJLsZA
#   Args:
#     a: 15
#     b: 7
# ================================= Tool Message =================================
# Name: multiply
#
# 105
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_RThqJug1SnaO4e5JIyOJLsZA)
#  Call ID: call_RThqJug1SnaO4e5JIyOJLsZA
#   Args:
#     a: 15
#     b: 7
# ================================= Tool Message =================================
# Name: multiply
#
# 105
# ================================== Ai Message ==================================
#
# Hi Akshit, the result of multiplying 15 and 7 is 105.
# ================================== Ai Message ==================================
#
# Hi Akshit, the result of multiplying 15 and 7 is 105.

# %% [markdown]
# Now, we can see our current state after the agent re-ran.

# %% [markdown]
# ## Forking
#
# What if we want to run from that same step, but with a different input.
#
# This is forking.
#
# ![fig3.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbb038f89f2d847ee5c336_time-travel3.png)

# %%
to_fork = all_states[-2]
to_fork.values["messages"]
# Out:
# [HumanMessage(content="Hi, I'm Akshit. Please multiply 15 and 7.", additional_kwargs={}, response_metadata={}, id='faa74a8e-e7ee-4750-bd64-cf1c4313e2a5')]

# %% [markdown]
# Again, we have the config.

# %%
to_fork.config
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0b3fbf-1f88-64a0-8000-97ad8c1ded76'}}

# %% [markdown]
# Let's modify the state at this checkpoint.
#
# We can just run `update_state` with the `checkpoint_id` supplied.
#
# Remember how our reducer on `messages` works:
#
# * It will append, unless we supply a message ID.
# * We supply the message ID to overwrite the message, rather than appending to state!
#
# So, to overwrite the the message, we just supply the message ID, which we have `to_fork.values["messages"].id`.

# %%
fork_config = graph.update_state(
    to_fork.config,
    {"messages": [HumanMessage(content='Hi, I\'m Akshit. Please add 42 and 58.',
                               id=to_fork.values["messages"][0].id)]},
)

# %%
fork_config
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0b3fbf-6595-68f1-8001-2a64e5953e06'}}

# %% [markdown]
# This creates a new, forked checkpoint.
#
# But, the metadata - e.g., where to go next - is perserved!
#
# We can see the current state of our agent has been updated with our fork.

# %%
all_states = [state for state in graph.get_state_history(thread) ]
all_states[0].values["messages"]
# Out:
# [HumanMessage(content="Hi, I'm Akshit. Please add 42 and 58.", additional_kwargs={}, response_metadata={}, id='faa74a8e-e7ee-4750-bd64-cf1c4313e2a5'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 169, 'total_tokens': 186, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_65564d8ba5', 'id': 'chatcmpl-CVdMX03NLtFv3TTQedwp9GgiOofLA', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--dfda36c8-9cc6-486b-800c-cd0d5b69e49f-0', tool_calls=[{'name': 'multiply', 'args': {'a': 15, 'b': 7}, 'id': 'call_np6Jxh541Gw6NyeSos9eBMF0', 'type': 'tool_call'}], usage_metadata={'input_tokens': 169, 'output_tokens': 17, 'total_tokens': 186, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
graph.get_state({'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content="Hi, I'm Akshit. Please add 42 and 58.", additional_kwargs={}, response_metadata={}, id='faa74a8e-e7ee-4750-bd64-cf1c4313e2a5'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 169, 'total_tokens': 186, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_65564d8ba5', 'id': 'chatcmpl-CVdMX03NLtFv3TTQedwp9GgiOofLA', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--dfda36c8-9cc6-486b-800c-cd0d5b69e49f-0', tool_calls=[{'name': 'multiply', 'args': {'a': 15, 'b': 7}, 'id': 'call_np6Jxh541Gw6NyeSos9eBMF0', 'type': 'tool_call'}], usage_metadata={'input_tokens': 169, 'output_tokens': 17, 'total_tokens': 186, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('tools',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b3fbf-6595-68f1-8001-2a64e5953e06'}}, metadata={'source': 'update', 'step': 1, 'parents': {}}, created_at='2025-10-28T12:45:19.969918+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b3fbf-1f88-64a0-8000-97ad8c1ded76'}}, tasks=(PregelTask(id='f2bc5a2a-de0e-1486-ea90-311352cc72c9', name='tools', path=('__pregel_pull', 'tools'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %% [markdown]
# Now, when we stream, the graph knows this checkpoint has never been executed.
#
# So, the graph runs, rather than simply re-playing.

# %%
for event in graph.stream(None, fork_config, stream_mode="values"):
    event['messages'][-1].pretty_print()
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_np6Jxh541Gw6NyeSos9eBMF0)
#  Call ID: call_np6Jxh541Gw6NyeSos9eBMF0
#   Args:
#     a: 15
#     b: 7
# ================================= Tool Message =================================
# Name: multiply
#
# 105
# ================================== Ai Message ==================================
#
# Hi Akshit, the sum of 42 and 58 is 100.
# ================================== Ai Message ==================================
#
# Hi Akshit, the sum of 42 and 58 is 100.

# %% [markdown]
# Now, we can see the current state is the end of our agent run.

# %%
graph.get_state({'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content="Hi, I'm Akshit. Please add 42 and 58.", additional_kwargs={}, response_metadata={}, id='faa74a8e-e7ee-4750-bd64-cf1c4313e2a5'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 169, 'total_tokens': 186, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_65564d8ba5', 'id': 'chatcmpl-CVdMX03NLtFv3TTQedwp9GgiOofLA', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--dfda36c8-9cc6-486b-800c-cd0d5b69e49f-0', tool_calls=[{'name': 'multiply', 'args': {'a': 15, 'b': 7}, 'id': 'call_np6Jxh541Gw6NyeSos9eBMF0', 'type': 'tool_call'}], usage_metadata={'input_tokens': 169, 'output_tokens': 17, 'total_tokens': 186, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='105', name='multiply', id='69cc0ac4-a405-4b87-bcbe-483ec5d71496', tool_call_id='call_np6Jxh541Gw6NyeSos9eBMF0'), AIMessage(content='Hi Akshit, the sum of 42 and 58 is 100.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 194, 'total_tokens': 211, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_65564d8ba5', 'id': 'chatcmpl-CVdMfFSWRhsH3bLAgLnZVsrXmvEPa', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--da8541c6-daac-4064-8802-155c10dffa7f-0', usage_metadata={'input_tokens': 194, 'output_tokens': 17, 'total_tokens': 211, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b3fbf-7cdc-6907-8003-200c737bf7d3'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2025-10-28T12:45:22.409729+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0b3fbf-67f9-64b7-8002-b8c446ef015d'}}, tasks=(), interrupts=())

# %% [markdown]
# ### Time travel with LangGraph API
#
# **⚠️ Notice**
#
# Since filming these videos, we've updated Studio so that it can now be run locally and accessed through your browser. This is the preferred way to run Studio instead of using the Desktop App shown in the video. It is now called _LangSmith Studio_ instead of _LangGraph Studio_. Detailed setup instructions are available in the "Getting Setup" guide at the start of the course. You can find a description of Studio [here](https://docs.langchain.com/langsmith/studio), and specific details for local deployment [here](https://docs.langchain.com/langsmith/quick-start-studio#local-development-server).
# To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the **Studio UI** URL shown above.
#
# We connect to it via the SDK and show how the LangGraph API [supports time travel](https://langchain-ai.github.io/langgraph/cloud/how-tos/human_in_the_loop_time_travel/#initial-invocation).

# %%
if 'google.colab' in str(get_ipython()):
    raise Exception("Unfortunately LangGraph Studio is currently not supported on Google Colab")

# %%
from langgraph_sdk import get_client
client = get_client(url="http://127.0.0.1:2024")

# %% [markdown]
# #### Re-playing
#
# Let's run our agent streaming `updates` to the state of the graph after each node is called.

# %%
initial_input = {"messages": HumanMessage(content="Hi, I'm Akshit. Please multiply 15 and 7.")}
thread = await client.threads.create()
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id = "agent",
    input=initial_input,
    stream_mode="updates",
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_NPSRjpkE9lxBiWUJLOqaJptS', 'function': {'arguments': '{"a":15,"b":7}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 142, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdMzarZXByNlmx5VJhp34t5OkXUe', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--0725315f-8be6-42c7-bf91-680ef93d9d8f-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 15, 'b': 7}, 'id': 'call_NPSRjpkE9lxBiWUJLOqaJptS', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 142, 'output_tokens': 17, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}
# --------------------Tools Node--------------------
# {'content': '105', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'fee63d32-1b68-4ccc-8714-e4c56c2149e7', 'tool_call_id': 'call_NPSRjpkE9lxBiWUJLOqaJptS', 'artifact': None, 'status': 'success'}
# --------------------Tools Node--------------------
# {'content': '105', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'fee63d32-1b68-4ccc-8714-e4c56c2149e7', 'tool_call_id': 'call_NPSRjpkE9lxBiWUJLOqaJptS', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'Hi Akshit, the result of multiplying 15 and 7 is 105.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 18, 'prompt_tokens': 167, 'total_tokens': 185, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdN2jrHFI87KfJEnsThVoqUp8HdX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--66ff280d-bcc8-4875-aad6-52cff5ebe201-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 167, 'output_tokens': 18, 'total_tokens': 185, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}
# --------------------Assistant Node--------------------
# {'content': 'Hi Akshit, the result of multiplying 15 and 7 is 105.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 18, 'prompt_tokens': 167, 'total_tokens': 185, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdN2jrHFI87KfJEnsThVoqUp8HdX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--66ff280d-bcc8-4875-aad6-52cff5ebe201-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 167, 'output_tokens': 18, 'total_tokens': 185, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}

# %% [markdown]
# Now, let's look at **replaying** from a specified checkpoint.
#
# We simply need to pass the `checkpoint_id`.

# %%
states = await client.threads.get_history(thread['thread_id'])
to_replay = states[-2]
to_replay
# Out:
# {'values': {'messages': [{'content': "Hi, I'm Akshit. Please multiply 15 and 7.",
#     'additional_kwargs': {},
#     'response_metadata': {},
#     'type': 'human',
#     'name': None,
#     'id': 'f20c5e3a-fba9-45b6-9544-e65a3417302c'}]},
#  'next': ['assistant'],
#  'tasks': [{'id': '6a3f1ca1-2c33-17a5-77dd-c4e089232a12',
#    'name': 'assistant',
#    'path': ['__pregel_pull', 'assistant'],
#    'error': None,
#    'interrupts': [],
#    'checkpoint': None,
#    'state': None,
#    'result': {'messages': [{'content': '',
#       'additional_kwargs': {'tool_calls': [{'id': 'call_NPSRjpkE9lxBiWUJLOqaJptS',
#          'function': {'arguments': '{"a":15,"b":7}', 'name': 'multiply'},
#          'type': 'function'}],
#        'refusal': None},
#       'response_metadata': {'token_usage': {'completion_tokens': 17,
#         'prompt_tokens': 142,
#         'total_tokens': 159,
#         'completion_tokens_details': {'accepted_prediction_tokens': 0,
#          'audio_tokens': 0,
#          'reasoning_tokens': 0,
#          'rejected_prediction_tokens': 0},
#         'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}},
#        'model_name': 'gpt-4o-2024-08-06',
#        'system_fingerprint': 'fp_cbf1785567',
#        'id': 'chatcmpl-CVdMzarZXByNlmx5VJhp34t5OkXUe',
#        'service_tier': 'default',
#        'finish_reason': 'tool_calls',
#        'logprobs': None},
#       'type': 'ai',
#       'name': None,
#       'id': 'lc_run--0725315f-8be6-42c7-bf91-680ef93d9d8f-0',
#       'tool_calls': [{'name': 'multiply',
#         'args': {'a': 15, 'b': 7},
#         'id': 'call_NPSRjpkE9lxBiWUJLOqaJptS',
#         'type': 'tool_call'}],
#       'invalid_tool_calls': [],
#       'usage_metadata': {'input_tokens': 142,
#        'output_tokens': 17,
#        'total_tokens': 159,
#        'input_token_details': {'audio': 0, 'cache_read': 0},
#        'output_token_details': {'audio': 0, 'reasoning': 0}}}]}}],
#  'metadata': {'langgraph_auth_user': None,
#   'langgraph_auth_user_id': '',
#   'langgraph_auth_permissions': [],
#   'langgraph_request_id': '0a9232bc-7a11-4902-85c1-13542479a3bc',
#   'graph_id': 'agent',
#   'assistant_id': 'fe096781-5601-53d2-b2f6-0d3403f7e9ca',
#   'user_id': '',
#   'created_by': 'system',
#   'run_attempt': 1,
#   'langgraph_version': '1.0.0',
#   'langgraph_api_version': '0.4.46',
#   'langgraph_plan': 'developer',
#   'langgraph_host': 'self-hosted',
#   'langgraph_api_url': 'http://127.0.0.1:2024',
#   'run_id': '019a2ada-352d-7682-a678-dda514c856c2',
#   'thread_id': '958c4d7d-906f-4b6c-ae5d-9b586936c344',
#   'source': 'loop',
#   'step': 0,
#   'parents': {}},
#  'created_at': '2025-10-28T12:45:38.342872+00:00',
#  'checkpoint': {'checkpoint_id': '1f0b3fc0-14cd-6671-8000-8b913513bf83',
#   'thread_id': '958c4d7d-906f-4b6c-ae5d-9b586936c344',
#   'checkpoint_ns': ''},
#  'parent_checkpoint': {'checkpoint_id': '1f0b3fc0-0bbf-6fa5-bfff-6fc91a65f659',
#   'thread_id': '958c4d7d-906f-4b6c-ae5d-9b586936c344',
#   'checkpoint_ns': ''},
#  'interrupts': [],
#  'checkpoint_id': '1f0b3fc0-14cd-6671-8000-8b913513bf83',
#  'parent_checkpoint_id': '1f0b3fc0-0bbf-6fa5-bfff-6fc91a65f659'}

# %% [markdown]
# Let's stream with `stream_mode="values"` to see the full state at every node as we replay.

# %%
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=None,
    stream_mode="values",
    checkpoint_id=to_replay['checkpoint_id']
):      
    print(f"Receiving new event of type: {chunk.event}...")
    print(chunk.data)
    print("\n\n")
# Out:
# Receiving new event of type: metadata...
# {'run_id': '019a2ada-6917-7055-9f77-bd8700e89fc3', 'attempt': 1}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': "Hi, I'm Akshit. Please multiply 15 and 7.", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'f20c5e3a-fba9-45b6-9544-e65a3417302c'}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': "Hi, I'm Akshit. Please multiply 15 and 7.", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'f20c5e3a-fba9-45b6-9544-e65a3417302c'}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'function': {'arguments': '{"a":15,"b":7}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 142, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdN7LiBYUMlbXqAWAi3agfqEhxjX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--a48a2498-c81d-4ffa-af9c-7ab7c8961d53-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 15, 'b': 7}, 'id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 142, 'output_tokens': 17, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': "Hi, I'm Akshit. Please multiply 15 and 7.", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'f20c5e3a-fba9-45b6-9544-e65a3417302c'}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'function': {'arguments': '{"a":15,"b":7}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 142, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdN7LiBYUMlbXqAWAi3agfqEhxjX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--a48a2498-c81d-4ffa-af9c-7ab7c8961d53-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 15, 'b': 7}, 'id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 142, 'output_tokens': 17, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '105', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'e071f89c-52fd-4617-ae02-40d989312abc', 'tool_call_id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'artifact': None, 'status': 'success'}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': "Hi, I'm Akshit. Please multiply 15 and 7.", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'f20c5e3a-fba9-45b6-9544-e65a3417302c'}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'function': {'arguments': '{"a":15,"b":7}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 142, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdN7LiBYUMlbXqAWAi3agfqEhxjX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--a48a2498-c81d-4ffa-af9c-7ab7c8961d53-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 15, 'b': 7}, 'id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 142, 'output_tokens': 17, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': "Hi, I'm Akshit. Please multiply 15 and 7.", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'f20c5e3a-fba9-45b6-9544-e65a3417302c'}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'function': {'arguments': '{"a":15,"b":7}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 142, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdN7LiBYUMlbXqAWAi3agfqEhxjX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--a48a2498-c81d-4ffa-af9c-7ab7c8961d53-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 15, 'b': 7}, 'id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 142, 'output_tokens': 17, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '105', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'e071f89c-52fd-4617-ae02-40d989312abc', 'tool_call_id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'artifact': None, 'status': 'success'}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': "Hi, I'm Akshit. Please multiply 15 and 7.", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'f20c5e3a-fba9-45b6-9544-e65a3417302c'}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'function': {'arguments': '{"a":15,"b":7}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 142, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdN7LiBYUMlbXqAWAi3agfqEhxjX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--a48a2498-c81d-4ffa-af9c-7ab7c8961d53-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 15, 'b': 7}, 'id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 142, 'output_tokens': 17, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '105', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'e071f89c-52fd-4617-ae02-40d989312abc', 'tool_call_id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'artifact': None, 'status': 'success'}, {'content': 'Hi Akshit, the product of 15 and 7 is 105.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 167, 'total_tokens': 184, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdN8Ox2rd1JYm6whQo8yS9gjf62U', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--9acce3a5-63b9-4cf4-b4bf-4ee274ffbc9c-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 167, 'output_tokens': 17, 'total_tokens': 184, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': "Hi, I'm Akshit. Please multiply 15 and 7.", 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'f20c5e3a-fba9-45b6-9544-e65a3417302c'}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'function': {'arguments': '{"a":15,"b":7}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 142, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdN7LiBYUMlbXqAWAi3agfqEhxjX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--a48a2498-c81d-4ffa-af9c-7ab7c8961d53-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 15, 'b': 7}, 'id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 142, 'output_tokens': 17, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '105', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'e071f89c-52fd-4617-ae02-40d989312abc', 'tool_call_id': 'call_X9mMwPdOBmbK3QmI5Y1pcL48', 'artifact': None, 'status': 'success'}, {'content': 'Hi Akshit, the product of 15 and 7 is 105.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 167, 'total_tokens': 184, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdN8Ox2rd1JYm6whQo8yS9gjf62U', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--9acce3a5-63b9-4cf4-b4bf-4ee274ffbc9c-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 167, 'output_tokens': 17, 'total_tokens': 184, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}]}

# %% [markdown]
# We can all view this as streaming only `updates` to state made by the nodes that we reply.

# %%
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=None,
    stream_mode="updates",
    checkpoint_id=to_replay['checkpoint_id']
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_4gLwBnGMTsKMnhJI2CYlsvCd', 'function': {'arguments': '{"a":15,"b":7}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 142, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdNB7bR8alUHLDzORpMfsxLggfDI', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--b33612bb-8b84-4394-add0-02189ab24872-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 15, 'b': 7}, 'id': 'call_4gLwBnGMTsKMnhJI2CYlsvCd', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 142, 'output_tokens': 17, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}
# --------------------Tools Node--------------------
# {'content': '105', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '1a058ed6-4a61-4615-9758-c76effc96b8e', 'tool_call_id': 'call_4gLwBnGMTsKMnhJI2CYlsvCd', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'Hi Akshit, the product of 15 and 7 is 105.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 167, 'total_tokens': 184, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdND4i9vf97zRVOcLD7KYeubltdU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--59380f88-b675-427f-b461-7e59431684e3-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 167, 'output_tokens': 17, 'total_tokens': 184, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}
# --------------------Assistant Node--------------------
# {'content': 'Hi Akshit, the product of 15 and 7 is 105.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 167, 'total_tokens': 184, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdND4i9vf97zRVOcLD7KYeubltdU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--59380f88-b675-427f-b461-7e59431684e3-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 167, 'output_tokens': 17, 'total_tokens': 184, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}

# %% [markdown]
# #### Forking
#
# Now, let's look at forking.
#
# Let's get the same step as we worked with above, the human input.
#
# Let's create a new thread with our agent.

# %%
initial_input = {"messages": HumanMessage(content="Hi, I'm Akshit. Please multiply 15 and 7.")}
thread = await client.threads.create()
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=initial_input,
    stream_mode="updates",
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_PvRWrpHccTh3t80fRL2xBtKJ', 'function': {'arguments': '{"a":15,"b":7}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 142, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdNFtSi4Yrkvv3GAyAmW2aqKNOIn', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--f88f2839-51b7-4ef0-93ff-347820a19d1e-0', 'tool_calls': [{'name': 'multiply', 'args': {'a': 15, 'b': 7}, 'id': 'call_PvRWrpHccTh3t80fRL2xBtKJ', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 142, 'output_tokens': 17, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}
# --------------------Tools Node--------------------
# {'content': '105', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '0dab09e4-d274-43c3-8b9b-9032c8bd3b07', 'tool_call_id': 'call_PvRWrpHccTh3t80fRL2xBtKJ', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'Hello Akshit, the result of multiplying 15 and 7 is 105.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 18, 'prompt_tokens': 167, 'total_tokens': 185, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdNKmdBN3poJ1yAh0gpMCocoOAYx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--bb2a264e-7d6e-44c2-b82e-1f97e4cdabc2-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 167, 'output_tokens': 18, 'total_tokens': 185, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}
# --------------------Assistant Node--------------------
# {'content': 'Hello Akshit, the result of multiplying 15 and 7 is 105.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 18, 'prompt_tokens': 167, 'total_tokens': 185, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdNKmdBN3poJ1yAh0gpMCocoOAYx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--bb2a264e-7d6e-44c2-b82e-1f97e4cdabc2-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 167, 'output_tokens': 18, 'total_tokens': 185, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}

# %%
states = await client.threads.get_history(thread['thread_id'])
to_fork = states[-2]
to_fork['values']
# Out:
# {'messages': [{'content': "Hi, I'm Akshit. Please multiply 15 and 7.",
#    'additional_kwargs': {},
#    'response_metadata': {},
#    'type': 'human',
#    'name': None,
#    'id': '94fbf539-fece-4c47-9686-b3e800582e0d'}]}

# %%
to_fork['values']['messages'][0]['id']
# Out:
# '94fbf539-fece-4c47-9686-b3e800582e0d'

# %%
to_fork['next']
# Out:
# ['assistant']

# %%
to_fork['checkpoint_id']
# Out:
# '1f0b3fc0-c541-69d0-8000-c2b81ce0b48b'

# %% [markdown]
# Let's edit the state.
#
# Remember how our reducer on `messages` works:
#
# * It will append, unless we supply a message ID.
# * We supply the message ID to overwrite the message, rather than appending to state!

# %%
forked_input = {"messages": HumanMessage(content="Hi, I'm Akshit. Please add 42 and 58.",
                                         id=to_fork['values']['messages'][0]['id'])}

forked_config = await client.threads.update_state(
    thread["thread_id"],
    forked_input,
    checkpoint_id=to_fork['checkpoint_id']
)

# %%
forked_config
# Out:
# {'checkpoint': {'thread_id': 'd46c84b6-7c44-49d0-8250-a2c5f2841a0b',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0b3fc1-0aaf-642d-8001-98b61b7c21c6'},
#  'configurable': {'thread_id': 'd46c84b6-7c44-49d0-8250-a2c5f2841a0b',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0b3fc1-0aaf-642d-8001-98b61b7c21c6'},
#  'checkpoint_id': '1f0b3fc1-0aaf-642d-8001-98b61b7c21c6'}

# %%
states = await client.threads.get_history(thread['thread_id'])
states[0]
# Out:
# {'values': {'messages': [{'content': "Hi, I'm Akshit. Please add 42 and 58.",
#     'additional_kwargs': {},
#     'response_metadata': {},
#     'type': 'human',
#     'name': None,
#     'id': '94fbf539-fece-4c47-9686-b3e800582e0d'},
#    {'content': '',
#     'additional_kwargs': {'tool_calls': [{'id': 'call_PvRWrpHccTh3t80fRL2xBtKJ',
#        'function': {'arguments': '{"a":15,"b":7}', 'name': 'multiply'},
#        'type': 'function'}],
#      'refusal': None},
#     'response_metadata': {'token_usage': {'completion_tokens': 17,
#       'prompt_tokens': 142,
#       'total_tokens': 159,
#       'completion_tokens_details': {'accepted_prediction_tokens': 0,
#        'audio_tokens': 0,
#        'reasoning_tokens': 0,
#        'rejected_prediction_tokens': 0},
#       'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}},
#      'model_name': 'gpt-4o-2024-08-06',
#      'system_fingerprint': 'fp_cbf1785567',
#      'id': 'chatcmpl-CVdNFtSi4Yrkvv3GAyAmW2aqKNOIn',
#      'service_tier': 'default',
#      'finish_reason': 'tool_calls',
#      'logprobs': None},
#     'type': 'ai',
#     'name': None,
#     'id': 'lc_run--f88f2839-51b7-4ef0-93ff-347820a19d1e-0',
#     'tool_calls': [{'name': 'multiply',
#       'args': {'a': 15, 'b': 7},
#       'id': 'call_PvRWrpHccTh3t80fRL2xBtKJ',
#       'type': 'tool_call'}],
#     'invalid_tool_calls': [],
#     'usage_metadata': {'input_tokens': 142,
#      'output_tokens': 17,
#      'total_tokens': 159,
#      'input_token_details': {'audio': 0, 'cache_read': 0},
#      'output_token_details': {'audio': 0, 'reasoning': 0}}}]},
#  'next': ['tools'],
#  'tasks': [{'id': '686df7ea-4b89-62d5-7bda-7514df4a6986',
#    'name': 'tools',
#    'path': ['__pregel_pull', 'tools'],
#    'error': None,
#    'interrupts': [],
#    'checkpoint': None,
#    'state': None,
#    'result': None}],
#  'metadata': {'graph_id': 'agent',
#   'thread_id': 'd46c84b6-7c44-49d0-8250-a2c5f2841a0b',
#   'checkpoint_id': '1f0b3fc0-c541-69d0-8000-c2b81ce0b48b',
#   'checkpoint_ns': '',
#   'source': 'update',
#   'step': 1,
#   'parents': {}},
#  'created_at': '2025-10-28T12:46:04.125495+00:00',
#  'checkpoint': {'checkpoint_id': '1f0b3fc1-0aaf-642d-8001-98b61b7c21c6',
#   'thread_id': 'd46c84b6-7c44-49d0-8250-a2c5f2841a0b',
#   'checkpoint_ns': ''},
#  'parent_checkpoint': {'checkpoint_id': '1f0b3fc0-c541-69d0-8000-c2b81ce0b48b',
#   'thread_id': 'd46c84b6-7c44-49d0-8250-a2c5f2841a0b',
#   'checkpoint_ns': ''},
#  'interrupts': [],
#  'checkpoint_id': '1f0b3fc1-0aaf-642d-8001-98b61b7c21c6',
#  'parent_checkpoint_id': '1f0b3fc0-c541-69d0-8000-c2b81ce0b48b'}

# %% [markdown]
# To rerun, we pass in the `checkpoint_id`.

# %%
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=None,
    stream_mode="updates",
    checkpoint_id=forked_config['checkpoint_id']
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Tools Node--------------------
# {'content': '105', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '0cf23ad8-dde0-4ee0-9b2e-55713aa72205', 'tool_call_id': 'call_PvRWrpHccTh3t80fRL2xBtKJ', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_WUxgF8lwaLzAWFbPfiWfZNfv', 'function': {'arguments': '{"a":42,"b":58}', 'name': 'add'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 167, 'total_tokens': 184, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdNNozQbcyuCEKa1EFmfD81sCgwT', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--74e33e68-1e8d-4a31-9048-eddb5bb2a6a1-0', 'tool_calls': [{'name': 'add', 'args': {'a': 42, 'b': 58}, 'id': 'call_WUxgF8lwaLzAWFbPfiWfZNfv', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 167, 'output_tokens': 17, 'total_tokens': 184, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}
# --------------------Tools Node--------------------
# {'content': '100', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'add', 'id': 'f90d881c-0edd-4ef2-b468-110187879b94', 'tool_call_id': 'call_WUxgF8lwaLzAWFbPfiWfZNfv', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_WUxgF8lwaLzAWFbPfiWfZNfv', 'function': {'arguments': '{"a":42,"b":58}', 'name': 'add'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 167, 'total_tokens': 184, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdNNozQbcyuCEKa1EFmfD81sCgwT', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--74e33e68-1e8d-4a31-9048-eddb5bb2a6a1-0', 'tool_calls': [{'name': 'add', 'args': {'a': 42, 'b': 58}, 'id': 'call_WUxgF8lwaLzAWFbPfiWfZNfv', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 167, 'output_tokens': 17, 'total_tokens': 184, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}
# --------------------Tools Node--------------------
# {'content': '100', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'add', 'id': 'f90d881c-0edd-4ef2-b468-110187879b94', 'tool_call_id': 'call_WUxgF8lwaLzAWFbPfiWfZNfv', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'Hi Akshit, the sum of 42 and 58 is 100.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 192, 'total_tokens': 209, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdNQCAOXFoQafOq4xCPi58Z9ZoC2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--18e21e5b-78a4-44c2-9ce6-1c40af7a32b3-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 192, 'output_tokens': 17, 'total_tokens': 209, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}
# --------------------Assistant Node--------------------
# {'content': 'Hi Akshit, the sum of 42 and 58 is 100.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 192, 'total_tokens': 209, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVdNQCAOXFoQafOq4xCPi58Z9ZoC2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'lc_run--18e21e5b-78a4-44c2-9ce6-1c40af7a32b3-0', 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 192, 'output_tokens': 17, 'total_tokens': 209, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}

# %% [markdown]
# ### LangGraph Studio
#
# Let's look at forking in the Studio UI with our `agent`, which uses `module-1/studio/agent.py` set in `module-1/studio/langgraph.json`.
